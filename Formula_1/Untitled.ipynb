# %%
# %load_ext autoreload
# %autoreload 2

try:
    del formula1_statistics
except:
    pass 

from formula1_statistics import YearStatistics, DriverStatistics
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 2021 Year Formula 1 Champinship

# %%
year_stat = YearStatistics(2023)

# %%
year_stat.constructors_championship()

# %%
year_stat.drivers_points_during_season()

# %%
year_stat.constructors_points_during_season()

# %%
year_stat.mean_start_position()
# Out:
#                     mean_start_position
# fullname
# Max Verstappen                     2.86
# Lewis Hamilton                     3.09
# Sergio Pérez                       4.41
# Valtteri Bottas                    5.59
# Pierre Gasly                       6.36
# Charles Leclerc                    6.45
# Lando Norris                       6.86
# Carlos Sainz                       7.91
# Daniel Ricciardo                   9.68
# Fernando Alonso                   10.50
# Esteban Ocon                      10.68
# Sebastian Vettel                  11.18
# Yuki Tsunoda                      11.50
# Antonio Giovinazzi                12.82
# George Russell                    13.00
# Lance Stroll                      13.09
# Kimi Räikkönen                    13.40
# Nicholas Latifi                   15.23
# Robert Kubica                     16.50
# Mick Schumacher                   17.55
# Nikita Mazepin                    18.50

# %%
year_stat.median_start_position()
# Out:
#                     grid
# fullname
# Lewis Hamilton       1.0
# Valtteri Bottas      2.0
# Max Verstappen       3.0
# Sergio Pérez         5.0
# Alexander Albon      6.0
# Daniel Ricciardo     7.0
# Carlos Sainz         8.0
# Lando Norris         8.0
# Charles Leclerc      8.0
# Lance Stroll         8.5
# Esteban Ocon        10.0
# Pierre Gasly        10.0
# Sebastian Vettel    11.0
# Daniil Kvyat        12.0
# Nico Hülkenberg     13.0
# George Russell      15.0
# Kimi Räikkönen      16.0
# Romain Grosjean     16.0
# Kevin Magnussen     16.0
# Jack Aitken         17.0
# Antonio Giovinazzi  17.0
# Pietro Fittipaldi   18.5
# Nicholas Latifi     19.0

# %%
year_stat.mean_points()
# Out:
#               fullname  mean_points
# 0       Max Verstappen        17.66
# 1       Lewis Hamilton        17.52
# 2      Valtteri Bottas         9.95
# 3         Sergio Pérez         8.64
# 4         Carlos Sainz         7.43
# 5         Lando Norris         7.27
# 6      Charles Leclerc         7.23
# 7     Daniel Ricciardo         5.18
# 8         Pierre Gasly         5.00
# 9      Fernando Alonso         3.68
# 10        Esteban Ocon         3.36
# 11    Sebastian Vettel         1.95
# 12        Lance Stroll         1.55
# 13        Yuki Tsunoda         1.45
# 14      George Russell         0.73
# 15      Kimi Räikkönen         0.50
# 16     Nicholas Latifi         0.32
# 17  Antonio Giovinazzi         0.14
# 18     Mick Schumacher         0.00
# 19      Nikita Mazepin         0.00
# 20       Robert Kubica         0.00

# %%
year_stat.percent_of_finishes()
# Out:
# '83.24 %'

# %%
year_stat.start_finish_correlation()

# %%
driver_stat = DriverStatistics('Fernando Alonso')

# %%
driver_stat.podiums_results()
# Out:
# Fernando Alonso podiums statistics:
#          team_name podium_position  count
# 0   Alpine F1 Team           total      1
# 1   Alpine F1 Team               3      1
# 2     Aston Martin           total      6
# 3     Aston Martin               3      4
# 4     Aston Martin               2      2
# 5          Ferrari           total     44
# 6          Ferrari               2     18
# 7          Ferrari               3     15
# 8          Ferrari               1     11
# 9          McLaren           total     12
# 10         McLaren               1      4
# 11         McLaren               3      4
# 12         McLaren               2      4
# 13         Renault           total     41
# 14         Renault               1     17
# 15         Renault               2     15
# 16         Renault               3      9
# 17           total           total    104
